# %%
'''Image Visualization
'''

import pprint
from PIL import Image
import matplotlib.pyplot as plt
# %matplotlib inline
from skimage import io
import numpy as np

# helper func.
def show_image(path_list):
    row = len(path_list[0])
    col = len(path_list)
    fig = plt.figure(figsize=(row*5,col*8))
    fig.tight_layout()
    for j, data in enumerate(path_list):
        for i, path in enumerate(data):
            ax = plt.subplot2grid((col,row), (j,i))
            ax.spines['bottom'].set_linewidth(5.5)
            ax.spines['top'].set_linewidth(5.5)
            ax.spines['left'].set_linewidth(5.5)
            ax.spines['right'].set_linewidth(5.5)
            if i == 0:
                ax.spines['bottom'].set_color('green')
                ax.spines['top'].set_color('green')
                ax.spines['left'].set_color('green')
                ax.spines['right'].set_color('green')
            else:
                ax.spines['bottom'].set_color('red')
                ax.spines['top'].set_color('red')
                ax.spines['left'].set_color('red')
                ax.spines['right'].set_color('red')
                    
            ax.set_xticks([])
            ax.set_yticks([])
            im = get_image_from_path(path)
            plt.imshow(im)
    plt.show()


def get_image_from_path(image_path, crop_bbox=None):
    # download the image, convert it to a NumPy array, and then read
    # it into OpenCV format
    try:
        img = io.imread(image_path)
    except Exception as e:
        print("exception:", e)
        img = None

    if img is None or len(img.shape) > 3:
        img = np.zeros((1, 1, 3))
    try:
        img = img[:, :, :3]
    except Exception as e:
        print(img.shape)
        img = np.zeros((1, 1, 3))

    if crop_bbox:
        x_st = crop_bbox[0]
        y_st = crop_bbox[1]
        x_en = crop_bbox[2]
        y_en = crop_bbox[3]
        crop_img = img[y_st:y_en, x_st:x_en]
        img = crop_img

    return img

# Main
image_path1 = [
['/home1/irteam/users/nashory/dataset/nfd-cc-indiv/539f37ef2e154425804964228472d311/539f37ef2e154425804964228472d311-6b345caf.jpg','/home1/irteam/users/nashory/dataset/nfd-cc-indiv/0647c2a85794432da0e58f3b3da2aaf8/0647c2a85794432da0e58f3b3da2aaf8-d0072d6f.jpg', '/home1/irteam/users/nashory/dataset/nfd-cc-indiv/04da77145aa84a5a93bbaad6ef3fc56d/04da77145aa84a5a93bbaad6ef3fc56d-a6fd3fd0.jpg', '/home1/irteam/users/nashory/dataset/nfd-cc-indiv/8054616a4f084ec78e09a6853877819d/8054616a4f084ec78e09a6853877819d-1ba4c5dc.jpg']
]
image_path2 = [
['/home1/irteam/users/nashory/dataset/nfd-cc-indiv/27f3c78ba66041a8aebb9c64a1c6089d/27f3c78ba66041a8aebb9c64a1c6089d-a37c1945.jpg','/home1/irteam/users/nashory/dataset/nfd-cc-indiv/969ff87b7d754087afad7904ffac21d4/969ff87b7d754087afad7904ffac21d4-2b222164.jpg', '/home1/irteam/users/nashory/dataset/nfd-cc-indiv/1ff1d89cdca6463dbc856f3cfcb66303/1ff1d89cdca6463dbc856f3cfcb66303-d4d144d9.jpg', '/home1/irteam/users/nashory/dataset/nfd-cc-indiv/3a6fc57d7c684d9d89ad6745b3b6fcb6/3a6fc57d7c684d9d89ad6745b3b6fcb6-80d6ee3f.jpg'],  
]
image_path3 = [
['/home1/irteam/users/nashory/dataset/nfd-cc-indiv/446e3f59a5d248b588ee32a1d86901f8/446e3f59a5d248b588ee32a1d86901f8-e5ff486b.jpg','/home1/irteam/users/nashory/dataset/nfd-cc-indiv/9a4d726333cd4176a80c7316e10cec03/9a4d726333cd4176a80c7316e10cec03-7f5ae505.jpg', '/home1/irteam/users/nashory/dataset/nfd-cc-indiv/9a4d726333cd4176a80c7316e10cec03/9a4d726333cd4176a80c7316e10cec03-4e77503c.jpg', '/home1/irteam/users/nashory/dataset/nfd-cc-indiv/9a4d726333cd4176a80c7316e10cec03/9a4d726333cd4176a80c7316e10cec03-c5d4f36f.jpg']
]
image_path4 = [
['/home1/irteam/users/nashory/dataset/nfd-cc-indiv